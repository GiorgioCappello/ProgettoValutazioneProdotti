# %%
# Pricing digital option modello CEV con metodo Crank-Nicholson (theta = 0.5)

import math as mt
import numpy as np

# %%
## input

# mercato
r = 0.001
S0 = 1
K = 1
T = 1
# calibrazione
sigma = 0.4
beta = 0.5
# discretizzazione
M = 1500
N = 1000
# theta metodo (Crank-Nicholson)
theta = 0.5

# %%
# griglia

Smin = 0.2*S0
Smax = 4*S0

dS = (Smax-Smin)/N
dt = T/M

S = np.zeros((N+1,1))
for i in range(0,N+1):
    S[i,0] = Smin + i*dS

# %%
# Costruisco matrice
A = np.zeros((N+1,N+1))
A[0,0]=1
for i in range(1,N):
    A[i,i-1] = (1-theta)*(-(r*S[i,0])/(2*dS) + sigma**2/(2*dS**2)*(S[i,0]**(2*(beta))))     
    A[i,i] = -1/dt + (1-theta)*(-sigma**2/(dS**2)*(S[i,0]**(2*(beta))) - r)                 
    A[i,i+1] = (1-theta)*((r*S[i,0])/(2*dS) + sigma**2/(2*dS**2)*(S[i,0]**(2*(beta))))     
A[-1,-1] = 1

# Matrice rhs
B = np.zeros((N+1,N+1))
for i in range(1,N):
    B[i,i-1] = (-theta)*(-(r*S[i,0])/(2*dS) + sigma**2/(2*dS**2)*(S[i,0]**(2*(beta))))
    B[i,i] = -1/dt + (-theta)*(-sigma**2/(dS**2)*(S[i,0]**(2*(beta))) - r)
    B[i,i+1] = (-theta)*((r*S[i,0])/(2*dS) + sigma**2/(2*dS**2)*(S[i,0]**(2*(beta))))

# %%
# Condizione finale

f = np.zeros((N+1,1))
for i in range(0,N+1):
    f[i,0] = 1 if (S[i,0]>K) else 0  

from matplotlib import pyplot as plt
plt.plot(S,f)

# %%
# Backward in time
rhs = np.zeros((N+1,1))
bc = np.zeros((N+1,1))
for j in range(M,0,-1):
    # termine noto sistema lineare
    bc[0,0] = 0
    bc[N,0] = mt.exp(-r*(T-(j-1)*dt))
    rhs = np.matmul(B,f)
    rhs = np.add(rhs,bc)
    # risolvo il sistema lineare
    f = np.linalg.solve(A,rhs)
plt.plot(S,f)

# %%
# Calcolare il prezzo
S = S.flatten() # da matrice a vettore
f = f.flatten()
Prezzo = np.interp(S0, S, f)
print(Prezzo)
# Out:
# 0.4213934982082692

# %%
# Calcolo del prezzo sotto l'ipotesi che il sottostante evolve come moto browniano geometrivo BSM 
# (HA SENSO CALCOLARLO SOLO PER BETA = 1)

if beta == 1:
    from math import log, sqrt, exp
    from scipy.stats import norm

    def d2(S,K,r,T,sigma):
        return (log(S/K)+(r-sigma**2/2)*T)/(sigma*sqrt(T))

    PrezzoBS = exp(-r*T)*norm.cdf(d2(S0,K,r,T,sigma))

    print(PrezzoBS)
# Out:
# 0.42129663336761874
